# %% [markdown]
# # CNN pour la classification d'images
#
# Ce notebook est conçu pour classifier les images de spectrogrammes de moteurs sains et défectueux à l'aide d'un réseau de neurones convolutifs (CNN). Le modèle s'appuiera sur un réseau pré-entraîné comme base pour l'apprentissage par transfert.

# %%
# Importer les bibliothèques nécessaires
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from PIL import Image

# Définir le chemin de base
base_dir = "../../data/05_cnn_input"

# Fonction pour charger et empiler les 3 images (X, Y, Z) en un seul tableau
# Chaque image est redimensionnée à une taille uniforme (224x224)
def load_and_stack_images(image_paths):
    images = [np.array(Image.open(path).resize((224, 224))) for path in image_paths]
    return np.stack(images, axis=-1)  # Empiler les images le long de l'axe des canaux

print("Base dir =" + base_dir)
# Out:
# Base dir =../../data/05_cnn_input

# %%
# Diviser les données en trois groupes : entraînement, validation et test
from sklearn.model_selection import train_test_split
import shutil

# Chemins des dossiers d'entrée
input_balourd = os.path.join(base_dir, 'balourd')
print("input_balourd = " + input_balourd)
input_sain = os.path.join(base_dir, 'sain')
print("input_sain = " + input_sain)

# Afficher le contenu des dossiers d'entrée pour vérification
print("Contenu du dossier balourd :", os.listdir(input_balourd))
print("Contenu du dossier sain :", os.listdir(input_sain))



# Créer les dossiers pour les ensembles divisés
for group in ['train', 'val', 'test']:
    for category in ['balourd', 'sain']:
        os.makedirs(os.path.join(base_dir, group, category), exist_ok=True)

# Fonction pour diviser et copier les fichiers
# Mise à jour pour gérer les 3 images (X, Y, Z) par donnée

def split_and_copy(input_dir, output_dirs, split_ratios):
    files = os.listdir(input_dir)
    print(f"Fichiers dans {input_dir} : {files}")  # Vérification des fichiers d'entrée
    grouped_files = {}

    # Grouper les fichiers par préfixe (X, Y, Z)
    for file in files:
        prefix = file.rsplit('_', 1)[0]  # Supposer que les fichiers sont nommés comme "nom_X.ext"
        if prefix not in grouped_files:
            grouped_files[prefix] = []
        grouped_files[prefix].append(file)

    # Vérifier que chaque groupe a exactement 3 fichiers
    grouped_files = {k: v for k, v in grouped_files.items() if len(v) == 3}
    print(f"Groupes détectés dans {input_dir} : {grouped_files}")  # Vérification des groupes

    # Vérifier si des groupes valides existent
    if not grouped_files:
        raise ValueError(f"Aucun groupe valide trouvé dans {input_dir}. Vérifiez les fichiers.")

    # Diviser les groupes en ensembles d'entraînement, validation et test
    prefixes = list(grouped_files.keys())
    train_prefixes, temp_prefixes = train_test_split(prefixes, test_size=(1 - split_ratios[0]))
    val_prefixes, test_prefixes = train_test_split(temp_prefixes, test_size=(split_ratios[2] / (split_ratios[1] + split_ratios[2])))

    # Copier les fichiers dans les dossiers correspondants
    for prefixes, output_dir in zip([train_prefixes, val_prefixes, test_prefixes], output_dirs):
        print(f"Copie des fichiers vers {output_dir}")  # Vérification des chemins de destination
        for prefix in prefixes:
            for file in grouped_files[prefix]:
                shutil.copy(os.path.join(input_dir, file), output_dir)



# Diviser les fichiers pour chaque catégorie
split_and_copy(input_balourd, [
    os.path.join(base_dir, 'train', 'balourd'),
    os.path.join(base_dir, 'val', 'balourd'),
    os.path.join(base_dir, 'test', 'balourd')
], [0.7, 0.2, 0.1])

split_and_copy(input_sain, [
    os.path.join(base_dir, 'train', 'sain'),
    os.path.join(base_dir, 'val', 'sain'),
    os.path.join(base_dir, 'test', 'sain')
], [0.7, 0.2, 0.1])
# Out:
# input_balourd = ../../data/05_cnn_input/balourd
# input_sain = ../../data/05_cnn_input/sain
# Contenu du dossier balourd : ['spec_rgb_0551.png', 'spec_rgb_0552.png', 'spec_rgb_0553.png', 'spec_rgb_0554.png', 'spec_rgb_0555.png', 'spec_rgb_0556.png', 'spec_rgb_0557.png', 'spec_rgb_0558.png', 'spec_rgb_0559.png', 'spec_rgb_0560.png', 'spec_rgb_0561.png', 'spec_rgb_0562.png', 'spec_rgb_0563.png', 'spec_rgb_0564.png', 'spec_rgb_0565.png', 'spec_rgb_0566.png', 'spec_rgb_0567.png', 'spec_rgb_0568.png', 'spec_rgb_0569.png', 'spec_rgb_0570.png', 'spec_rgb_0571.png', 'spec_rgb_0572.png', 'spec_rgb_0573.png', 'spec_rgb_0574.png', 'spec_rgb_0575.png', 'spec_rgb_0576.png', 'spec_rgb_0577.png', 'spec_rgb_0578.png', 'spec_rgb_0579.png', 'spec_rgb_0580.png', 'spec_rgb_0581.png', 'spec_rgb_0582.png', 'spec_rgb_0583.png', 'spec_rgb_0584.png', 'spec_rgb_0585.png', 'spec_rgb_0586.png', 'spec_rgb_0587.png', 'spec_rgb_0588.png', 'spec_rgb_0589.png', 'spec_rgb_0590.png', 'spec_rgb_0591.png', 'spec_rgb_0592.png', 'spec_rgb_0593.png', 'spec_rgb_0594.png', 'spec_rgb_0595.png', 'spec_rgb_0596.png', 'spec_rgb_0597.png', 'spec_rgb_0598.png', 'spec_rgb_0599.png', 'spec_rgb_0600.png', 'spec_rgb_0601.png', 'spec_rgb_0602.png', 'spec_rgb_0603.png', 'spec_rgb_0604.png', 'spec_rgb_0605.png', 'spec_rgb_0606.png', 'spec_rgb_0607.png', 'spec_rgb_0608.png', 'spec_rgb_0609.png', 'spec_rgb_0610.png', 'spec_rgb_0611.png', 'spec_rgb_0612.png', 'spec_rgb_0613.png', 'spec_rgb_0614.png', 'spec_rgb_0615.png', 'spec_rgb_0616.png', 'spec_rgb_0617.png', 'spec_rgb_0618.png', 'spec_rgb_0619.png', 'spec_rgb_0620.png', 'spec_rgb_0621.png', 'spec_rgb_0622.png', 'spec_rgb_0623.png', 'spec_rgb_0624.png', 'spec_rgb_0625.png', 'spec_rgb_0626.png', 'spec_rgb_0627.png', 'spec_rgb_0628.png', 'spec_rgb_0629.png', 'spec_rgb_0630.png', 'spec_rgb_0631.png', 'spec_rgb_0632.png', 'spec_rgb_0633.png', 'spec_rgb_0634.png', 'spec_rgb_0635.png', 'spec_rgb_0636.png', 'spec_rgb_0637.png', 'spec_rgb_0638.png', 'spec_rgb_0639.png', 'spec_rgb_0640.png', 'spec_rgb_0641.png', 'spec_rgb_0642.png', 'spec_rgb_0643.png', 'spec_rgb_0644.png', 'spec_rgb_0645.png', 'spec_rgb_0646.png', 'spec_rgb_0647.png', 'spec_rgb_0648.png', 'spec_rgb_0649.png', 'spec_rgb_0650.png', 'spec_rgb_0651.png', 'spec_rgb_0652.png', 'spec_rgb_0653.png', 'spec_rgb_0654.png', 'spec_rgb_0655.png', 'spec_rgb_0656.png', 'spec_rgb_0657.png', 'spec_rgb_0658.png', 'spec_rgb_0659.png', 'spec_rgb_0660.png', 'spec_rgb_0661.png', 'spec_rgb_0662.png', 'spec_rgb_0663.png', 'spec_rgb_0664.png', 'spec_rgb_0665.png', 'spec_rgb_0666.png', 'spec_rgb_0667.png', 'spec_rgb_0668.png', 'spec_rgb_0669.png', 'spec_rgb_0670.png', 'spec_rgb_0671.png', 'spec_rgb_0672.png', 'spec_rgb_0673.png', 'spec_rgb_0674.png', 'spec_rgb_0675.png', 'spec_rgb_0676.png', 'spec_rgb_0677.png', 'spec_rgb_0678.png', 'spec_rgb_0679.png', 'spec_rgb_0680.png', 'spec_rgb_0681.png', 'spec_rgb_0682.png', 'spec_rgb_0683.png', 'spec_rgb_0684.png', 'spec_rgb_0685.png', 'spec_rgb_0686.png', 'spec_rgb_0687.png', 'spec_rgb_0688.png', 'spec_rgb_0689.png', 'spec_rgb_0690.png', 'spec_rgb_0691.png', 'spec_rgb_0692.png', 'spec_rgb_0693.png', 'spec_rgb_0694.png', 'spec_rgb_0695.png', 'spec_rgb_0696.png', 'spec_rgb_0697.png', 'spec_rgb_0698.png', 'spec_rgb_0699.png', 'spec_rgb_0700.png', 'spec_rgb_0701.png', 'spec_rgb_0702.png', 'spec_rgb_0703.png', 'spec_rgb_0704.png', 'spec_rgb_0705.png', 'spec_rgb_0706.png', 'spec_rgb_0707.png', 'spec_rgb_0708.png', 'spec_rgb_0709.png', 'spec_rgb_0710.png', 'spec_rgb_0711.png', 'spec_rgb_0712.png', 'spec_rgb_0713.png', 'spec_rgb_0714.png', 'spec_rgb_0715.png', 'spec_rgb_0716.png', 'spec_rgb_0717.png', 'spec_rgb_0718.png', 'spec_rgb_0719.png', 'spec_rgb_0720.png', 'spec_rgb_0721.png', 'spec_rgb_0722.png', 'spec_rgb_0723.png', 'spec_rgb_0724.png', 'spec_rgb_0725.png', 'spec_rgb_0726.png', 'spec_rgb_0727.png', 'spec_rgb_0728.png', 'spec_rgb_0729.png', 'spec_rgb_0730.png', 'spec_rgb_0731.png', 'spec_rgb_0732.png', 'spec_rgb_0733.png', 'spec_rgb_0734.png', 'spec_rgb_0735.png', 'spec_rgb_0736.png', 'spec_rgb_0737.png', 'spec_rgb_0738.png', 'spec_rgb_0739.png', ' ...
# Contenu du dossier sain : ['spec_rgb_0000.png', 'spec_rgb_0001.png', 'spec_rgb_0002.png', 'spec_rgb_0003.png', 'spec_rgb_0004.png', 'spec_rgb_0005.png', 'spec_rgb_0006.png', 'spec_rgb_0007.png', 'spec_rgb_0008.png', 'spec_rgb_0009.png', 'spec_rgb_0010.png', 'spec_rgb_0011.png', 'spec_rgb_0012.png', 'spec_rgb_0013.png', 'spec_rgb_0014.png', 'spec_rgb_0015.png', 'spec_rgb_0016.png', 'spec_rgb_0017.png', 'spec_rgb_0018.png', 'spec_rgb_0019.png', 'spec_rgb_0020.png', 'spec_rgb_0021.png', 'spec_rgb_0022.png', 'spec_rgb_0023.png', 'spec_rgb_0024.png', 'spec_rgb_0025.png', 'spec_rgb_0026.png', 'spec_rgb_0027.png', 'spec_rgb_0028.png', 'spec_rgb_0029.png', 'spec_rgb_0030.png', 'spec_rgb_0031.png', 'spec_rgb_0032.png', 'spec_rgb_0033.png', 'spec_rgb_0034.png', 'spec_rgb_0035.png', 'spec_rgb_0036.png', 'spec_rgb_0037.png', 'spec_rgb_0038.png', 'spec_rgb_0039.png', 'spec_rgb_0040.png', 'spec_rgb_0041.png', 'spec_rgb_0042.png', 'spec_rgb_0043.png', 'spec_rgb_0044.png', 'spec_rgb_0045.png', 'spec_rgb_0046.png', 'spec_rgb_0047.png', 'spec_rgb_0048.png', 'spec_rgb_0049.png', 'spec_rgb_0050.png', 'spec_rgb_0051.png', 'spec_rgb_0052.png', 'spec_rgb_0053.png', 'spec_rgb_0054.png', 'spec_rgb_0055.png', 'spec_rgb_0056.png', 'spec_rgb_0057.png', 'spec_rgb_0058.png', 'spec_rgb_0059.png', 'spec_rgb_0060.png', 'spec_rgb_0061.png', 'spec_rgb_0062.png', 'spec_rgb_0063.png', 'spec_rgb_0064.png', 'spec_rgb_0065.png', 'spec_rgb_0066.png', 'spec_rgb_0067.png', 'spec_rgb_0068.png', 'spec_rgb_0069.png', 'spec_rgb_0070.png', 'spec_rgb_0071.png', 'spec_rgb_0072.png', 'spec_rgb_0073.png', 'spec_rgb_0074.png', 'spec_rgb_0075.png', 'spec_rgb_0076.png', 'spec_rgb_0077.png', 'spec_rgb_0078.png', 'spec_rgb_0079.png', 'spec_rgb_0080.png', 'spec_rgb_0081.png', 'spec_rgb_0082.png', 'spec_rgb_0083.png', 'spec_rgb_0084.png', 'spec_rgb_0085.png', 'spec_rgb_0086.png', 'spec_rgb_0087.png', 'spec_rgb_0088.png', 'spec_rgb_0089.png', 'spec_rgb_0090.png', 'spec_rgb_0091.png', 'spec_rgb_0092.png', 'spec_rgb_0093.png', 'spec_rgb_0094.png', 'spec_rgb_0095.png', 'spec_rgb_0096.png', 'spec_rgb_0097.png', 'spec_rgb_0098.png', 'spec_rgb_0099.png', 'spec_rgb_0100.png', 'spec_rgb_0101.png', 'spec_rgb_0102.png', 'spec_rgb_0103.png', 'spec_rgb_0104.png', 'spec_rgb_0105.png', 'spec_rgb_0106.png', 'spec_rgb_0107.png', 'spec_rgb_0108.png', 'spec_rgb_0109.png', 'spec_rgb_0110.png', 'spec_rgb_0111.png', 'spec_rgb_0112.png', 'spec_rgb_0113.png', 'spec_rgb_0114.png', 'spec_rgb_0115.png', 'spec_rgb_0116.png', 'spec_rgb_0117.png', 'spec_rgb_0118.png', 'spec_rgb_0119.png', 'spec_rgb_0120.png', 'spec_rgb_0121.png', 'spec_rgb_0122.png', 'spec_rgb_0123.png', 'spec_rgb_0124.png', 'spec_rgb_0125.png', 'spec_rgb_0126.png', 'spec_rgb_0127.png', 'spec_rgb_0128.png', 'spec_rgb_0129.png', 'spec_rgb_0130.png', 'spec_rgb_0131.png', 'spec_rgb_0132.png', 'spec_rgb_0133.png', 'spec_rgb_0134.png', 'spec_rgb_0135.png', 'spec_rgb_0136.png', 'spec_rgb_0137.png', 'spec_rgb_0138.png', 'spec_rgb_0139.png', 'spec_rgb_0140.png', 'spec_rgb_0141.png', 'spec_rgb_0142.png', 'spec_rgb_0143.png', 'spec_rgb_0144.png', 'spec_rgb_0145.png', 'spec_rgb_0146.png', 'spec_rgb_0147.png', 'spec_rgb_0148.png', 'spec_rgb_0149.png', 'spec_rgb_0150.png', 'spec_rgb_0151.png', 'spec_rgb_0152.png', 'spec_rgb_0153.png', 'spec_rgb_0154.png', 'spec_rgb_0155.png', 'spec_rgb_0156.png', 'spec_rgb_0157.png', 'spec_rgb_0158.png', 'spec_rgb_0159.png', 'spec_rgb_0160.png', 'spec_rgb_0161.png', 'spec_rgb_0162.png', 'spec_rgb_0163.png', 'spec_rgb_0164.png', 'spec_rgb_0165.png', 'spec_rgb_0166.png', 'spec_rgb_0167.png', 'spec_rgb_0168.png', 'spec_rgb_0169.png', 'spec_rgb_0170.png', 'spec_rgb_0171.png', 'spec_rgb_0172.png', 'spec_rgb_0173.png', 'spec_rgb_0174.png', 'spec_rgb_0175.png', 'spec_rgb_0176.png', 'spec_rgb_0177.png', 'spec_rgb_0178.png', 'spec_rgb_0179.png', 'spec_rgb_0180.png', 'spec_rgb_0181.png', 'spec_rgb_0182.png', 'spec_rgb_0183.png', 'spec_rgb_0184.png', 'spec_rgb_0185.png', 'spec_rgb_0186.png', 'spec_rgb_0187.png', 'spec_rgb_0188.png', 'spe ...
# Groupes détectés dans ../../data/05_cnn_input/balourd : {}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 59
#      55                 shutil.copy(os.path.join(input_dir, file), output_dir)
#      58 # Diviser les fichiers pour chaque catégorie
# ---> 59 split_and_copy(input_balourd, [
#      60     os.path.join(base_dir, 'train', 'balourd'),
#      61     os.path.join(base_dir, 'val', 'balourd'),
#      62     os.path.join(base_dir, 'test', 'balourd')
#      63 ], [0.7, 0.2, 0.1])
#      65 split_and_copy(input_sain, [
#      66     os.path.join(base_dir, 'train', 'sain'),
#      67     os.path.join(base_dir, 'val', 'sain'),
#      68     os.path.join(base_dir, 'test', 'sain')
#      69 ], [0.7, 0.2, 0.1])
#
# Cell In[22], line 44, in split_and_copy(input_dir, output_dirs, split_ratios)
#      42 # Vérifier si des groupes valides existent
#      43 if not grouped_files:
# ---> 44     raise ValueError(f"Aucun groupe valide trouvé dans {input_dir}. Vérifiez les fichiers.")
#      46 # Diviser les groupes en ensembles d'entraînement, validation et test
#      47 prefixes = list(grouped_files.keys())
#
# ValueError: Aucun groupe valide trouvé dans ../../data/05_cnn_input/balourd. Vérifiez les fichiers.

# %%
# Charger le modèle VGG16 pré-entraîné sans la couche supérieure
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Geler les couches du modèle de base
for layer in base_model.layers:
    layer.trainable = False

# Construire le modèle CNN
model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compiler le modèle
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Afficher le résumé du modèle
model.summary()

# %%
# Entraîner le modèle uniquement avec le train set
history = model.fit(
    train_data,
    epochs=10,
    validation_data=val_data
)

# Sauvegarder le modèle
model_dir = os.path.join(os.path.dirname(os.path.abspath(__file__)), '..', '..', 'model')
os.makedirs(model_dir, exist_ok=True)
model_path = os.path.join(model_dir, 'cnn_model.h5')
model.save(model_path)
print(f"Modèle sauvegardé à : {model_path}")

# %%
# Évaluer le modèle sur les données de test
eval_loss, eval_acc = model.evaluate(test_data)
print(f"Perte sur les données de test : {eval_loss}")
print(f"Précision sur les données de test : {eval_acc}")
